# %% [markdown]
# ## Experiments on selecting best optimizer

# %%
import sys
sys.path.append("../")
from algorithms import Evals
optimiser_option = ["SGD", "Momentum", "Adam"]
eval_dict = Evals.set_exp(exps= optimiser_option, exp_name= 'optimiser')
eval_df = Evals.run_exp(exp_dict= eval_dict, epochs= 50)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\James\Anaconda3\envs\pytorch\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# -----------------Running: SGD----------------------
# Epoch: 5  Training Loss: 1.6035642889174295  Time (sec) per epoch: 3.927170515060425
# Epoch: 10  Training Loss: 1.3759866069561493  Time (sec) per epoch: 3.8458924293518066
# Epoch: 15  Training Loss: 1.1914931447139925  Time (sec) per epoch: 3.8224239349365234
# Epoch: 20  Training Loss: 1.1157979510302711  Time (sec) per epoch: 3.9238481521606445
# Epoch: 25  Training Loss: 1.0707000887742268  Time (sec) per epoch: 3.9200403690338135
# Epoch: 30  Training Loss: 1.041832908554896  Time (sec) per epoch: 3.943675994873047
# ...

# %%
eval_df
# Out:
#   Hyperparameters                                               loss  \
# 0             SGD  [2.3086764143437644, 1.909083528506686, 1.7455...
# 1        Momentum  [2.3569875013835158, 1.9315855779151043, 1.759...
# 2            Adam  [1.7119804595232524, 1.4769519097032189, 1.357...
#
#    train_acc  valid_acc  train_precision  valid_precision  train_recall  \
# 0   0.784325     0.5301         0.779000         0.523177      0.784584
# 1   0.800125     0.5216         0.794155         0.515743      0.800175
# 2   0.913800     0.5045         0.923177         0.492033      0.914176
#
#    valid_recall  train_f1  valid_f1       times
# 0      0.528893  0.774641  0.520937  195.443788
# 1      0.520517  0.792816  0.515995  166.191884
# 2      0.502900  0.907897  0.495442  206.973917

# %% [markdown]
# ## Experiments on selecting best dropout ratio

# %%
keep_rate_option = [1,0.8,0.5,0.2]
eval_dict_drop = Evals.set_exp(exps= keep_rate_option, exp_name= 'keep_prob')
eval_df_drop = Evals.run_exp(exp_dict= eval_dict_drop, epochs= 50)
# Out:
# -----------------Running: 1----------------------
# Epoch: 5  Training Loss: 1.1996387335176255  Time (sec) per epoch: 4.15744161605835
# Epoch: 10  Training Loss: 1.0068675938650313  Time (sec) per epoch: 4.272107362747192
# Epoch: 15  Training Loss: 0.90748165460514  Time (sec) per epoch: 4.018623113632202
# Epoch: 20  Training Loss: 0.8444625093038787  Time (sec) per epoch: 4.149883985519409
# Epoch: 25  Training Loss: 0.803782977300645  Time (sec) per epoch: 3.9720911979675293
# Epoch: 30  Training Loss: 0.7705558111855865  Time (sec) per epoch: 4.002319097518921
# Epoch: 35  Training Loss: 0.7454321673728856  Time (sec) per epoch: 4.219544410705566
# Epoch: 40  Training Loss: 0.7249806342780546  Time (sec) per epoch: 3.988821268081665
# Epoch: 45  Training Loss: 0.7096938417198106  Time (sec) per epoch: 4.226586580276489
# Epoch: 50  Training Loss: 0.6993472965808596  Time (sec) per epoch: 4.218828916549683
# -----------------Running: 0.8----------------------
# ...

# %%
eval_df_drop
# Out:
#    Hyperparameters                                               loss  \
# 0              1.0  [1.7165047497878396, 1.4757288679696667, 1.354...
# 1              0.8  [1.8349394557885024, 1.6236640391015624, 1.529...
# 2              0.5  [2.1104903340671126, 1.9073377989683324, 1.840...
# 3              0.2  [2.3782566481134606, 2.2698344558455026, 2.267...
#
#    train_acc  valid_acc  train_precision  valid_precision  train_recall  \
# 0   0.941050     0.4998         0.950189         0.490904      0.941324
# 1   0.755625     0.5156         0.749061         0.501079      0.755743
# 2   0.539775     0.4410         0.503779         0.406017      0.540429
# 3   0.201575     0.1898         0.078333         0.079422      0.200749
#
#    valid_recall  train_f1  valid_f1       times
# 0      0.498384  0.938064  0.493147  206.926843
# 1      0.515285  0.738853  0.499579  213.326817
# 2      0.439080  0.492010  0.397489  208.015583
# 3      0.192759  0.091452  0.087054  204.214284

# %% [markdown]
# ## Experiments on selecitng best weight decay value

# %%
weight_decay_strength = [0.1,0.01,0.001,0]
eval_dict_wd = Evals.set_exp(exps= weight_decay_strength, exp_name= 'weight_decay')
eval_df_wd = Evals.run_exp(exp_dict= eval_dict_wd, epochs= 50)
# Out:
# -----------------Running: 0.1----------------------
# Epoch: 5  Training Loss: 1.563845993458521  Time (sec) per epoch: 4.339802265167236
# Epoch: 10  Training Loss: 1.9704830574438925  Time (sec) per epoch: 4.404975652694702
# Epoch: 15  Training Loss: 2.9062449351597444  Time (sec) per epoch: 4.357445955276489
# Epoch: 20  Training Loss: 4.371656518931445  Time (sec) per epoch: 4.367398023605347
# Epoch: 25  Training Loss: 6.345843871507427  Time (sec) per epoch: 4.2928407192230225
# Epoch: 30  Training Loss: 8.853742142945906  Time (sec) per epoch: 4.390058517456055
# Epoch: 35  Training Loss: 11.899889665729603  Time (sec) per epoch: 4.292169094085693
# Epoch: 40  Training Loss: 15.459073669323116  Time (sec) per epoch: 4.3618292808532715
# Epoch: 45  Training Loss: 19.570069693333096  Time (sec) per epoch: 4.3313682079315186
# Epoch: 50  Training Loss: 24.21128618326566  Time (sec) per epoch: 4.361809492111206
# -----------------Running: 0.01----------------------
# ...

# %%
eval_df_wd
